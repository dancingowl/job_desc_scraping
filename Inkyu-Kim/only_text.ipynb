# %%
from konlpy.tag import Komoran
import pandas as pd

# %%
# Komoran 형태소 분석기에서 사용자 사전 추가
tokenizer = Komoran(userdic = './user_dict.txt')

# %%
df = pd.read_csv('./desc_df.csv')
df
# Out:
#             Company                                        Description
# 0         0 데이터앤솔루션  세상의 모든 데이터를 관리하고 싶은 여러분께 열려 있습니다. - 인크루트 채용데이터...
# 1        1 (주)데이터트리  데이터트리 채용 : [현장코칭](주)데이터트리 DBA/DA 채용공고 - 인크루트 채...
# 2        2 (주)데이터누리  데이터누리 채용 : [(주)데이터누리] Java 개발자 신입, 경력 채용공고 - 인...
# 3         3 달리셔스(주)  빅데이터, 데이터분석 외 경력 정규직 채용 - 인크루트 채용달리셔스(주)빅데이터, ...
# 4      4 (주)한국복권데이터                                                NaN
# 5        5 주식회사 카카오  데이터 정책 및 데이터 자산 관리 담당자 모집 (경력) - 인크루트 채용데이터 정책...
# 6        6 주식회사 카카오  데이터 사이언티스트를 지향하는 데이터 엔지니어 모집 - 인크루트 채용데이터 사이언티...
# 7        7 (주)GS리테일                                                NaN
# 8      8 한국카카오은행(주)  [빅데이터플랫폼] 데이터웨어하우스 운영 담당자 - 인크루트 채용[빅데이터플랫폼] 데...
# 9           9 고려대학교  데이터Hub팀 데이터사이언티스트 채용공고 - 인크루트 채용고려대학교데이터Hub팀 데...
# 10      10 KB데이타시스템  빅데이터 전문가 - 인크루트 채용■ 모집부문 및 인원모집부문구분인원자격요건 및 우대...
# 11     11 (주)카카오게임즈  데이터 엔지니어 영입 - 인크루트 채용데이터 엔지니어 영입카카오게임즈는 카카오의 게...
# ...

# %%
a = [x for x in df['Description']]
a
# Out:
# ['세상의 모든 데이터를 관리하고 싶은 여러분께 열려 있습니다. - 인크루트 채용데이터앤솔루션세상의 모든 데이터를 관리하고 싶은 모든분께 열려있습니다모집부문 및 자격요건담당업무자격요건인원[담당업무]세상의 모든 데이터를 관리하고 싶으신 모든 분께 열려 있습니다.주 업무는 엑셀이나 프로그램을 사용하여, 표준화 규칙에 맞게 정리하는 작업으로,초급 이상, 중급 정도의 엑셀 사용능력이 있으신 분 환영합니다.[근무부서 및 직급/직책]근무부서: 빅데이터본부 자료관리팀직급/직책: 사원[자격요건]경력사항: 신입학력사항: 고등학교졸업 이상직무기술: 엑셀 사용 가능자기타: 엑셀 활용 가능자 우대0 명근무조건고용형태: 정규직(수습기간3개월)근무부서: 빅데이터본부 자료관리팀인근전철역: 서울3호선 남부터미널(예술의전당) (5번 출구에서 400m이내)급여조건: 연봉 회사내규전형단계 및 제출서류전형단계: 서류전형 > 면접진행 > 최종심사 > 최종합격추가 제출서류이력서에 연락처, 희망연봉 기재제출한 서류는 일체 반환하지 않음이력서, 자기소개서서류전형, 면접전형접수방법채용시접수방법: 인크루트 채용시스템접수양식: 인크루트 이력서기타 유의사항입사지원서 및 제출서류에 허위사실이 있을 경우 채용이 취소될 수 있습니다.',
# ...

# %%
'GCP' in stack
# Out:
# True

# %%
b = [x in a[1] for x in stack]
b
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
stack = ['AWS',
'GCP',
'HDFS',
'MR',
'Hadoop',
'Hbase',
'Spark',
'Docker',
'SQL',
'MySQL',
'MariaDB',
'GraphQL',
'Hive',
'Linux',
'Airflow',
'Kafka',
'Python',
'R',
'Scala',
'Keras',
'Pytorch',
'Sklearn',
'TensorFlow',
'Tensorflow',
'Cassandra',
'Postgres']
